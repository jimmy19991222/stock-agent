# %%
import akshare as ak

# 尝试获取单只股票的实时数据，而不是全市场
try:
    # 以贵州茅台为例
    stock_code = "600519"
    
    # 替代 ak.stock_zh_a_spot_em()
    single_stock_data = ak.stock_individual_info_em(symbol=stock_code)
    
    print(single_stock_data.head())
    
    # 如果成功，您可以从这个 DataFrame 中找到 '市盈率' 和 '市净率'
    # 注意：你需要查看这个接口返回的 DataFrame 的实际列名
    
except Exception as e:
    print(f"stock_individual_info_em 接口也失败了: {e}")
# Out:
#    item         value
# 0    最新       1443.99
# 1  股票代码        600519
# 2  股票简称          贵州茅台
# 3   总股本  1252270215.0
# 4   流通股  1252270215.0

# %%
import akshare as ak

stock_zh_a_spot_em_df = ak.stock_zh_a_spot_em()
print(stock_zh_a_spot_em_df)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File c:\Users\ifun\miniconda3\envs\stock\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# ...

# %%
import akshare as ak

stock_sh_a_spot_em_df = ak.stock_zh_a_spot_hist()
print(stock_sh_a_spot_em_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 import akshare as ak
# ----> 3 stock_sh_a_spot_em_df = ak.stock_zh_a_spot_hist()
#       4 print(stock_sh_a_spot_em_df)
#
# AttributeError: module 'akshare' has no attribute 'stock_zh_a_spot_hist'
